# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldenThrust/E_Africa_FoodBalanceSheets/blob/main/hamoye_food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hamoye Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget -o https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv
# Out:
# wget: https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv: No such file or directory

# %%
food_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='ISO-8859-1')

# %%
food_df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
food_df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
food_df.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
food_df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
foodin2017 = food_df[['Area', 'Y2017']]
foodin2017 = foodin2017.groupby('Area')['Y2017'].sum().reset_index()

# %%
max = foodin2017['Y2017'].idxmax()
foodin2017.loc[max]['Area']
# Out:
# 'Nigeria'

# %%
Winein20152018 = food_df[food_df['Item'].isin(['Wine'])]

# %%
Winein20152018.groupby('Item')[['Y2015','Y2018']].sum()
# Out:
#         Y2015    Y2018
# Item
# Wine  4251.81  4039.32

# %%
numofempty = food_df['Y2014'].isnull().sum()
food_df.shape[0]
# Out:
# 60943

# %%
numofempty
# Out:
# 1589

# %%
((numofempty / food_df.shape[0]) * 100)
# Out:
# 2.6073544131401474

# %%
element = food_df.groupby('Element')[['Element','Y2014', 'Y2015', 'Y2016', 'Y2017']].sum()
# Out:
# <ipython-input-16-e41627dc58de>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   element = food_df.groupby('Element')[['Element','Y2014', 'Y2015', 'Y2016', 'Y2017']].sum()

# %%
element.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Element'>

# %%
element.sum().idxmax()
# Out:
# 'Y2017'

# %%
correl = food_df.corr()['Element Code'][['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]
# Out:
# <ipython-input-19-46ea7996e247>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correl = food_df.corr()['Element Code'][['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']]

# %%
correl
# Out:
# Y2014    0.024457
# Y2015    0.023889
# Y2016    0.023444
# Y2017    0.024254
# Y2018    0.024279
# Name: Element Code, dtype: float64

# %%
correl.idxmin()
# Out:
# 'Y2016'

# %%
food_df['Area'].describe()['unique']
# Out:
# 49

# %%
len(food_df['Area'].unique())
# Out:
# 49

# %%
Y2017 = food_df['Y2017']

# %%
Y2017.mean()
# Out:
# 140.9177648602722

# %%
Y2017.std()
# Out:
# 1671.8623590567995

# %%
mad2015 = food_df[(food_df['Area'] == 'Madagascar') & (food_df['Element Code'] == 674)].groupby('Element')['Y2015'].sum()

# %%
mad2015
# Out:
# Element
# Protein supply quantity (g/capita/day)    173.05
# Name: Y2015, dtype: float64

# %%
food_df[['Element', 'Element Code']]
# Out:
#                                       Element  Element Code
# 0               Total Population - Both sexes           511
# 1                    Domestic supply quantity          5301
# 2               Food supply (kcal/capita/day)           664
# 3      Protein supply quantity (g/capita/day)           674
# 4          Fat supply quantity (g/capita/day)           684
# ...                                       ...           ...
# 60938                                    Food          5142
# 60939     Food supply quantity (kg/capita/yr)           645
# 60940           Food supply (kcal/capita/day)           664
# 60941  Protein supply quantity (g/capita/day)           674
# 60942      Fat supply quantity (g/capita/day)           684
#
# [60943 rows x 2 columns]
# ...

# %%
 Area2017 = food_df.groupby('Area')['Y2017'].sum().sort_values()

# %%
 Area2017
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
Area2017[Area2017 ==  Area2017[6]]
# Out:
# Area
# Guinea-Bissau    19102.77
# Name: Y2017, dtype: float64

# %%
proc_2017 = food_df[(food_df['Element Code'] == 5131)].groupby('Element')['Y2017'].sum()

# %%
proc_2017
# Out:
# Element
# Processing    292836.0
# Name: Y2017, dtype: float64
